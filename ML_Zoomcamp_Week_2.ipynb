# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-alves-one/-ML-Zoomcamp-Week-2/blob/main/ML_Zoomcamp_Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Goldsmiths University of London
# **Author....: Carlos Manuel de Oliveira Alves**<br>
# **Student..: cdeol003**<br>
# **Created..: 31/08/2022**

# %%
# download the data for the homework
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Out:
# --2022-08-31 13:36:08--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: ‘data.csv.1’
#
# data.csv.1          100%[===================>]   1.41M  --.-KB/s    in 0.06s
#
# 2022-08-31 13:36:08 (25.5 MB/s) - ‘data.csv.1’ saved [1475504/1475504]

# %%
# import libraries Numpy and Pandas
import numpy as np
import pandas as pd

# %%
# read and save the data from the homework
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %% [markdown]
# ###What is the average price of BMW cars in the dataset?

# %%
df[df.Make == 'BMW'].MSRP.mean()
# Out:
# 61546.76347305389

# %%
# group the dataframe by make
df.groupby('Make').MSRP.mean().round(3)
# Out:
# Make
# Acura              34887.587
# Alfa Romeo         61600.000
# Aston Martin      197910.376
# Audi               53452.113
# BMW                61546.763
# Bentley           247169.324
# Bugatti          1757223.667
# Buick              28206.612
# Cadillac           56231.317
# Chevrolet          28350.386
# Chrysler           26722.963
# Dodge              22390.059
# FIAT               22670.242
# Ferrari           238218.841
# Ford               27399.267
# GMC                30493.299
# Genesis            46616.667
# HUMMER             36464.412
# Honda              26674.341
# Hyundai            24597.036
# Infiniti           42394.212
# Kia                25310.173
# Lamborghini       331567.308
# Land Rover         67823.217
# Lexus              47549.069
# Lincoln            42839.829
# Lotus              69188.276
# Maserati          114207.707
# Maybach           546221.875
# Mazda              20039.383
# McLaren           239805.000
# Mercedes-Benz      71476.229
# Mitsubishi         21240.535
# Nissan             28583.432
# Oldsmobile         11542.540
# Plymouth            3122.902
# Pontiac            19321.548
# Porsche           101622.397
# Rolls-Royce       351130.645
# Saab               27413.505
# Scion              19932.500
# Spyker            213323.333
# Subaru             24827.504
# Suzuki             17907.208
# Tesla              85255.556
# Toyota             29030.016
# Volkswagen         28102.381
# Volvo              28541.160
# Name: MSRP, dtype: float64

# %% [markdown]
# ###Select a subset of cars after year 2015 (inclusive, i.e. 2015 and after). How many of them have missing values for Engine HP?

# %%
df[df.Year >= 2015]
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 32                  4.0            MANUAL  rear wheel drive              2.0
# 33                  4.0            MANUAL  rear wheel drive              2.0
# 34                  4.0            MANUAL  rear wheel drive              2.0
# 41                  4.0         AUTOMATIC  rear wheel drive              2.0
# 42                  4.0         AUTOMATIC  rear wheel drive              2.0
# ...                 ...               ...               ...              ...
# 11898               6.0  AUTOMATED_MANUAL  rear wheel drive              2.0
# 11899               6.0  AUTOMATED_MANUAL  rear wheel drive              2.0
# 11900               6.0  AUTOMATED_MANUAL  rear wheel drive              2.0
# 11901               4.0            MANUAL  rear wheel drive              2.0
# 11902               6.0  AUTOMATED_MANUAL  rear wheel drive              2.0
#
#                Market Category Vehicle Size Vehicle Style  highway MPG  \
# 32                 Performance      Compact   Convertible           35
# 33                 Performance      Compact   Convertible           35
# 34                 Performance      Compact   Convertible           35
# 41          Luxury,Performance      Compact         Coupe           35
# 42                      Luxury      Compact   Convertible           34
# ...                        ...          ...           ...          ...
# 11898  Luxury,High-Performance      Compact   Convertible           24
# 11899  Luxury,High-Performance      Compact   Convertible           24
# 11900  Luxury,High-Performance      Compact   Convertible           24
# 11901       Luxury,Performance      Compact   Convertible           34
# 11902  Luxury,High-Performance      Compact   Convertible           24
#
#        city mpg  Popularity   MSRP
# 32           26         819  27495
# 33           26         819  24995
# 34           26         819  28195
# 41           23        3916  32850
# 42           23        3916  38650
# ...         ...         ...    ...
# 11898        17        3916  56950
# 11899        17        3916  65800
# 11900        17        3916  57500
# 11901        22        3916  49700
# 11902        17        3916  66350
#
# [5995 rows x 16 columns]

# %%
df[df.Year >= 2015].isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df[df.Year >= 2015]['Engine HP'].isnull().sum()
# Out:
# 51

# %% [markdown]
# ###Calculate the average "Engine HP" in the dataset

# %%
mean_hp = df['Engine HP'].mean()
mean_hp
# Out:
# 249.38607007176023

# %% [markdown]
# ###Use the fillna method and to fill the missing values in "Engine HP" with the mean value from the previous step

# %%
df['Engine HP'].fillna(mean_hp).mean()
# Out:
# 249.38607007176023

# %% [markdown]
# ###Select all the "Rolls-Royce" cars from the dataset

# %%
df[df.Make == 'Rolls-Royce']
# Out:
#               Make                   Model  Year             Engine Fuel Type  \
# 2921   Rolls-Royce                Corniche  2001  premium unleaded (required)
# 3505   Rolls-Royce                    Dawn  2016  premium unleaded (required)
# 5275   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5276   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5277   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5278   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5279   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5280   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5281   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5282   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5283   Rolls-Royce                   Ghost  2014  premium unleaded (required)
# 5284   Rolls-Royce                   Ghost  2014  premium unleaded (required)
# 7443   Rolls-Royce               Park Ward  2001  premium unleaded (required)
# 7444   Rolls-Royce               Park Ward  2002  premium unleaded (required)
# 7553   Rolls-Royce           Phantom Coupe  2014  premium unleaded (required)
# 7554   Rolls-Royce           Phantom Coupe  2015  premium unleaded (required)
# 7555   Rolls-Royce           Phantom Coupe  2016  premium unleaded (required)
# 7556   Rolls-Royce  Phantom Drophead Coupe  2014  premium unleaded (required)
# 7557   Rolls-Royce  Phantom Drophead Coupe  2015  premium unleaded (required)
# 7558   Rolls-Royce  Phantom Drophead Coupe  2016  premium unleaded (required)
# 7559   Rolls-Royce                 Phantom  2014  premium unleaded (required)
# 7560   Rolls-Royce                 Phantom  2014  premium unleaded (required)
# 7561   Rolls-Royce                 Phantom  2015  premium unleaded (required)
# 7562   Rolls-Royce                 Phantom  2015  premium unleaded (required)
# 7563   Rolls-Royce                 Phantom  2016  premium unleaded (required)
# 7564   Rolls-Royce                 Phantom  2016  premium unleaded (required)
# 9431   Rolls-Royce           Silver Seraph  2001  premium unleaded (required)
# 9432   Rolls-Royce           Silver Seraph  2002  premium unleaded (required)
# 11448  Rolls-Royce                  Wraith  2014  premium unleaded (required)
# 11449  Rolls-Royce                  Wraith  2015  premium unleaded (required)
# 11450  Rolls-Royce                  Wraith  2016  premium unleaded (required)
#
#        Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 2921       325.0               8.0         AUTOMATIC  rear wheel drive
# 3505       563.0              12.0         AUTOMATIC  rear wheel drive
# 5275       563.0              12.0         AUTOMATIC  rear wheel drive
# 5276       563.0              12.0         AUTOMATIC  rear wheel drive
# 5277       563.0              12.0         AUTOMATIC  rear wheel drive
# 5278       563.0              12.0         AUTOMATIC  rear wheel drive
# 5279       563.0              12.0         AUTOMATIC  rear wheel drive
# 5280       563.0              12.0         AUTOMATIC  rear wheel drive
# 5281       563.0              12.0         AUTOMATIC  rear wheel drive
# 5282       563.0              12.0         AUTOMATIC  rear wheel drive
# 5283       563.0              12.0         AUTOMATIC  rear wheel drive
# 5284       563.0              12.0         AUTOMATIC  rear wheel drive
# 7443       322.0              12.0         AUTOMATIC  rear wheel drive
# 7444       322.0              12.0         AUTOMATIC  rear wheel drive
# 7553       453.0              12.0         AUTOMATIC  rear wheel drive
# 7554       453.0              12.0         AUTOMATIC  rear wheel drive
# 7555       453.0              12.0         AUTOMATIC  rear wheel drive
# 7556       453.0              12.0         AUTOMATIC  rear wheel drive
# 7557       453.0              12.0         AUTOMATIC  rear wheel drive
# 7558       453.0              12.0         AUTOMATIC  rear wheel drive
# 7559       453.0              12.0         AUTOMATIC  rear wheel drive
# 7560       453.0              12.0         AUTOMATIC  rear wheel drive
# 7561       453.0              12.0         AUTOMATIC  rear wheel drive
# 7562       453.0              12.0         AUTOMATIC  rear wheel drive
# 7563       453.0              12.0         AUTOMATIC  rear wheel drive
# 7564       453.0              12.0         AUTOMATIC  rear wheel drive
# 9431       322.0              12.0         AUTOMATIC  rear wheel drive
# 9432       322.0              12.0         AUTOMATIC  rear wheel drive
# 11448      624.0              12.0         AUTOMATIC  rear wheel drive
# 11449      624.0              12.0         AUTOMATIC  rear wheel drive
# 11450      624.0              12.0         AUTOMATIC  rear wheel drive
#
#        Number of Doors                 Market Category Vehicle Size  \
# 2921               2.0                   Exotic,Luxury        Large
# 3505               2.0  Exotic,Luxury,High-Performance        Large
# 5275               4.0       Exotic,Luxury,Performance        Large
# 5276               4.0       Exotic,Luxury,Performance        Large
# 5277               4.0       Exotic,Luxury,Performance        Large
# 5278               4.0       Exotic,Luxury,Performance        Large
# 5279               4.0       Exotic,Luxury,Performance        Large
# 5280               4.0       Exotic,Luxury,Performance        Large
# 5281               4.0       Exotic,Luxury,Performance        Large
# 5282               4.0       Exotic,Luxury,Performance        Large
# 5283               4.0       Exotic,Luxury,Performance        Large
# 5284               4.0       Exotic,Luxury,Performance        Large
# 7443               4.0                   Exotic,Luxury        Large
# 7444               4.0                   Exotic,Luxury        Large
# 7553               2.0       Exotic,Luxury,Performance        Large
# 7554               2.0       Exotic,Luxury,Performance        Large
# 7555               2.0       Exotic,Luxury,Performance        Large
# 7556               2.0       Exotic,Luxury,Performance        Large
# 7557               2.0       Exotic,Luxury,Performance        Large
# 7558               2.0       Exotic,Luxury,Performance        Large
# 7559               4.0       Exotic,Luxury,Performance        Large
# 7560               4.0       Exotic,Luxury,Performance        Large
# 7561               4.0       Exotic,Luxury,Performance        Large
# 7562               4.0       Exotic,Luxury,Performance        Large
# 7563               4.0       Exotic,Luxury,Performance        Large
# 7564               4.0       Exotic,Luxury,Performance        Large
# 9431               4.0                   Exotic,Luxury        Large
# 9432               4.0                   Exotic,Luxury        Large
# 11448              2.0  Exotic,Luxury,High-Performance        Large
# 11449              2.0  Exotic,Luxury,High-Performance        Large
# 11450              2.0  Exotic,Luxury,High-Performance        Large
#
#       Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 2921    Convertible           15        10          86  359990
# 3505    Convertible           19        12          86  335000
# 5275          Sedan           21        13          86  286750
# 5276          Sedan           21        13          86  319400
# 5277          Sedan           21        13          86  295850
# 5278          Sedan           21        13          86  329325
# 5279          Sedan           20        13          86  250000
# 5280          Sedan           20        13          86  290000
# 5281          Sedan           21        13          86  296000
# 5282          Sedan           21        13          86  256650
# 5283          Sedan           21        13          86  263200
# 5284          Sedan           21        13          86  303300
# 7443          Sedan           15        11          86  259900
# 7444          Sedan           15        11          86  262990
# 7553          Coupe           19        11          86  433550
# 7554          Coupe           19        11          86  438325
# 7555          Coupe           19        11          86  449525
# 7556    Convertible           19        11          86  474600
# 7557    Convertible           19        11          86  479775
# 7558    Convertible           19        11          86  492000
# 7559          Sedan           19        11          86  402940
# 7560          Sedan           19        11          86  474990
# 7561          Sedan           19        11          86  407400
# 7562          Sedan           19        11          86  480175
# 7563          Sedan           19        11          86  417825
# 7564          Sedan           19        11          86  492425
# 9431          Sedan           15        11          86  219900
# 9432          Sedan           15        11          86  229990
# 11448         Coupe           21        13          86  284900
# 11449         Coupe           21        13          86  294025
# 11450         Coupe           21        13          86  304350

# %% [markdown]
# ###Select only columns "Engine HP", "Engine Cylinders", "highway MPG"

# %%
# drop all duplicated rows using drop_duplicates method
df_rr = df[df.Make == 'Rolls-Royce'] [["Engine HP", "Engine Cylinders", "highway MPG"]].drop_duplicates()
df_rr
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
# get the numpy array with the data from previous step
X = df_rr.values
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %% [markdown]
# ###Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX

# %%
X.T
# Out:
# array([[325., 563., 563., 563., 322., 453., 624.],
#        [  8.,  12.,  12.,  12.,  12.,  12.,  12.],
#        [ 15.,  19.,  21.,  20.,  15.,  19.,  21.]])
